# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import datetime as dt

# %%
data_path = os.path.join(os.getcwd(), "..", "data")
dataset = pd.read_csv(os.path.join(data_path,"data_sample.csv"))
dataset["datetime_from"] = pd.to_datetime(dataset["datetime_from"],utc=True).dt.tz_convert("CET")

# %%
dataset.head()
# Out:
#               datetime_from    load    res    ppt  borders  curtailments  \
# 0 2025-01-01 00:00:00+01:00  4619.0  810.0  550.0    428.9           0.0
# 1 2025-01-01 00:15:00+01:00  4619.0  810.0  550.0    428.9           0.0
# 2 2025-01-01 00:30:00+01:00  4517.0  810.0  550.0    428.9           0.0
# 3 2025-01-01 00:45:00+01:00  4517.0  810.0  550.0    428.9           0.0
# 4 2025-01-01 01:00:00+01:00  4457.0  820.0  500.0    642.7           0.0
#
#    holiday  day_of_week_Friday  day_of_week_Monday  day_of_week_Saturday  \
# 0        1               False               False                 False
# 1        1               False               False                 False
# 2        1               False               False                 False
# 3        1               False               False                 False
# 4        1               False               False                 False
#
#    day_of_week_Sunday  day_of_week_Thursday  day_of_week_Tuesday  \
# 0               False                 False                False
# 1               False                 False                False
# 2               False                 False                False
# 3               False                 False                False
# 4               False                 False                False
#
#    day_of_week_Wednesday
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True

# %%
dataset.describe()
# Out:
#                load           res           ppt       borders  curtailments  \
# count  49532.000000  49532.000000  49532.000000  49432.000000  49532.000000
# mean    5684.394513   3275.046899    794.077708   -576.912948   -260.011368
# std     1191.446647   2372.920216    792.053659    991.724916    741.194820
# min     3165.000000    290.000000      0.000000  -2659.000000  -7159.400000
# 25%     4776.000000   1357.000000     86.000000  -1380.575000      0.000000
# 50%     5616.000000   2605.500000    611.000000   -664.100000      0.000000
# 75%     6416.000000   4800.000000   1243.000000    178.525000      0.000000
# max    10938.000000  10820.000000   3689.150000   2196.000000      0.000000
#
#             holiday
# count  49532.000000
# mean       0.036825
# std        0.188333
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(dataset.corr(),annot = True, fmt='.2g')
plt.show()

# %%
sns.pairplot(dataset, diag_kind="kde")
